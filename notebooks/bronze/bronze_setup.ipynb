# %% [markdown]
# # Setup — Medallion Schema Initialisation
#
# Creates the Bronze, Silver, and Gold schemas in the Lakehouse if they do not already exist.\
# Run this notebook once before the first pipeline execution, or as the first step in the master pipeline.

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS gold")

print("Schemas ready")
